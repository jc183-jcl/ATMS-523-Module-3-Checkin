# %% [markdown]
# # Merging Climate Datasets Exercise
#
# Work through this notebook to practice harmonizing and merging two climate datasets that differ in temporal cadence and spatial resolution.
#
# You will:
# - Load two public NOAA datasets directly from the cloud
# - Subset to the continental US (use 230°E–300°E in longitude since the data span 0–360°)
# - Use `xr.resample` to aggregate time and `xr.interp` to match grids
# - Combine the variables with `xr.merge` for joint analysis
#
# Refer back to the answer key after attempting each step.

# %% [markdown]
# ## 1. Setup

# %%
import matplotlib.pyplot as plt
import xarray as xr

try:
    import cartopy.crs as ccrs
    import cartopy.feature as cfeature
except ImportError:
    ccrs = None
    cfeature = None

TEMP_URL = "https://psl.noaa.gov/thredds/dodsC/Datasets/ncep.reanalysis/surface/air.sig995.2020.nc"
PRECIP_URL = "https://psl.noaa.gov/thredds/dodsC/Datasets/cpc_global_precip/precip.2020.nc"

LAT_RANGE = (20, 50)  # degrees North
LON_RANGE_360 = (230, 300)  # degrees East (equivalent to -130° to -60°)
LON_RANGE_180 = (-130, -60)  # convenience if a dataset uses -180° to 180°

TIME_RANGE = slice("2020-06-01", "2020-06-30")

# %% [markdown]
# ## 2. Load the datasets
#
# Open both remote datasets with `xr.open_dataset`, passing a reasonable chunk size for the time dimension. Assign the resulting objects to `air` and `precip`.

# %%
# TODO: load the air temperature and precipitation datasets.
# Example: air = xr.open_dataset(..., chunks={"time": 8})

air = xr.open_dataset(TEMP_URL, chunks={"time": 8})
precip = xr.open_dataset(PRECIP_URL, chunks={"time": 8})

print(air)

print(precip)

#raise NotImplementedError("Assign datasets to `air` and `precip`.")
# Out:
# <xarray.Dataset> Size: 62MB
# Dimensions:  (time: 1464, lat: 73, lon: 144)
# Coordinates:
#   * lat      (lat) float32 292B 90.0 87.5 85.0 82.5 ... -82.5 -85.0 -87.5 -90.0
#   * lon      (lon) float32 576B 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 12kB 2020-01-01 ... 2020-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 62MB dask.array<chunksize=(8, 73, 144), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time
# <xarray.Dataset> Size: 379MB
# Dimensions:  (time: 366, lat: 360, lon: 720)
# Coordinates:
#   * lat      (lat) float32 1kB 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * lon      (lon) float32 3kB 0.25 0.75 1.25 1.75 ... 358.2 358.8 359.2 359.8
#   * time     (time) datetime64[ns] 3kB 2020-01-01 2020-01-02 ... 2020-12-31
# Data variables:
#     precip   (time, lat, lon) float32 379MB dask.array<chunksize=(8, 360, 720), meta=np.ndarray>
# Attributes:
#     _NCProperties:                   version=1|netcdflibversion=4.4.1.1|hdf5l...
#     Conventions:                     CF-1.0
#     version:                         V1.0
#     title:                           CPC GLOBAL PRCP V1.0 RT
#     dataset_title:                   CPC GLOBAL PRCP V1.0
#     Source:                          ftp://ftp.cpc.ncep.noaa.gov/precip/CPC_U...
#     References:                      https://www.psl.noaa.gov/data/gridded/da...
#     history:                         Updated 2021-01-02 23:31:03
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 3. Subset to the continental United States and June 2020
#
# Select the bounding box provided above and limit the time range to June 2020 for both datasets. Store the results in `air_us` and `precip_us`.
# Remember that longitude runs from 0° to 360°, so select 230°E–300°E. Check whether each coordinate is ascending or descending before building the slice.

# %%
# TODO: subset both datasets using `sel`, handling coordinate ordering as needed.
TIME_RANGE = slice("2020-06-01", "2020-06-30")

air_us = air.sel(lat=slice(50,20), lon=slice(*LON_RANGE_360), time=TIME_RANGE)
precip_us = precip.sel(lat=slice(50, 20), lon=slice(*LON_RANGE_360), time=TIME_RANGE)

print(air_us)
print(precip_us)
#raise NotImplementedError("Create `air_us` and `precip_us`.")
# Out:
# <xarray.Dataset> Size: 182kB
# Dimensions:  (time: 120, lat: 13, lon: 29)
# Coordinates:
#   * lat      (lat) float32 52B 50.0 47.5 45.0 42.5 40.0 ... 27.5 25.0 22.5 20.0
#   * lon      (lon) float32 116B 230.0 232.5 235.0 237.5 ... 295.0 297.5 300.0
#   * time     (time) datetime64[ns] 960B 2020-06-01 ... 2020-06-30T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 181kB dask.array<chunksize=(8, 13, 29), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time
# <xarray.Dataset> Size: 1MB
# Dimensions:  (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * lat      (lat) float32 240B 49.75 49.25 48.75 48.25 ... 21.25 20.75 20.25
#   * lon      (lon) float32 560B 230.2 230.8 231.2 231.8 ... 298.8 299.2 299.8
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
# Data variables:
#     precip   (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>
# Attributes:
#     _NCProperties:                   version=1|netcdflibversion=4.4.1.1|hdf5l...
#     Conventions:                     CF-1.0
#     version:                         V1.0
#     title:                           CPC GLOBAL PRCP V1.0 RT
#     dataset_title:                   CPC GLOBAL PRCP V1.0
#     Source:                          ftp://ftp.cpc.ncep.noaa.gov/precip/CPC_U...
#     References:                      https://www.psl.noaa.gov/data/gridded/da...
#     history:                         Updated 2021-01-02 23:31:03
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
print(air_us["time"])
# Out:
# <xarray.DataArray 'time' (time: 120)> Size: 960B
# array(['2020-06-01T00:00:00.000000000', '2020-06-01T06:00:00.000000000',
#        '2020-06-01T12:00:00.000000000', '2020-06-01T18:00:00.000000000',
#        '2020-06-02T00:00:00.000000000', '2020-06-02T06:00:00.000000000',
#        '2020-06-02T12:00:00.000000000', '2020-06-02T18:00:00.000000000',
#        '2020-06-03T00:00:00.000000000', '2020-06-03T06:00:00.000000000',
#        '2020-06-03T12:00:00.000000000', '2020-06-03T18:00:00.000000000',
#        '2020-06-04T00:00:00.000000000', '2020-06-04T06:00:00.000000000',
#        '2020-06-04T12:00:00.000000000', '2020-06-04T18:00:00.000000000',
#        '2020-06-05T00:00:00.000000000', '2020-06-05T06:00:00.000000000',
#        '2020-06-05T12:00:00.000000000', '2020-06-05T18:00:00.000000000',
#        '2020-06-06T00:00:00.000000000', '2020-06-06T06:00:00.000000000',
#        '2020-06-06T12:00:00.000000000', '2020-06-06T18:00:00.000000000',
#        '2020-06-07T00:00:00.000000000', '2020-06-07T06:00:00.000000000',
#        '2020-06-07T12:00:00.000000000', '2020-06-07T18:00:00.000000000',
#        '2020-06-08T00:00:00.000000000', '2020-06-08T06:00:00.000000000',
#        '2020-06-08T12:00:00.000000000', '2020-06-08T18:00:00.000000000',
#        '2020-06-09T00:00:00.000000000', '2020-06-09T06:00:00.000000000',
#        '2020-06-09T12:00:00.000000000', '2020-06-09T18:00:00.000000000',
#        '2020-06-10T00:00:00.000000000', '2020-06-10T06:00:00.000000000',
#        '2020-06-10T12:00:00.000000000', '2020-06-10T18:00:00.000000000',
#        '2020-06-11T00:00:00.000000000', '2020-06-11T06:00:00.000000000',
#        '2020-06-11T12:00:00.000000000', '2020-06-11T18:00:00.000000000',
#        '2020-06-12T00:00:00.000000000', '2020-06-12T06:00:00.000000000',
#        '2020-06-12T12:00:00.000000000', '2020-06-12T18:00:00.000000000',
#        '2020-06-13T00:00:00.000000000', '2020-06-13T06:00:00.000000000',
#        '2020-06-13T12:00:00.000000000', '2020-06-13T18:00:00.000000000',
#        '2020-06-14T00:00:00.000000000', '2020-06-14T06:00:00.000000000',
#        '2020-06-14T12:00:00.000000000', '2020-06-14T18:00:00.000000000',
#        '2020-06-15T00:00:00.000000000', '2020-06-15T06:00:00.000000000',
#        '2020-06-15T12:00:00.000000000', '2020-06-15T18:00:00.000000000',
#        '2020-06-16T00:00:00.000000000', '2020-06-16T06:00:00.000000000',
#        '2020-06-16T12:00:00.000000000', '2020-06-16T18:00:00.000000000',
#        '2020-06-17T00:00:00.000000000', '2020-06-17T06:00:00.000000000',
#        '2020-06-17T12:00:00.000000000', '2020-06-17T18:00:00.000000000',
#        '2020-06-18T00:00:00.000000000', '2020-06-18T06:00:00.000000000',
#        '2020-06-18T12:00:00.000000000', '2020-06-18T18:00:00.000000000',
#        '2020-06-19T00:00:00.000000000', '2020-06-19T06:00:00.000000000',
#        '2020-06-19T12:00:00.000000000', '2020-06-19T18:00:00.000000000',
#        '2020-06-20T00:00:00.000000000', '2020-06-20T06:00:00.000000000',
#        '2020-06-20T12:00:00.000000000', '2020-06-20T18:00:00.000000000',
#        '2020-06-21T00:00:00.000000000', '2020-06-21T06:00:00.000000000',
#        '2020-06-21T12:00:00.000000000', '2020-06-21T18:00:00.000000000',
#        '2020-06-22T00:00:00.000000000', '2020-06-22T06:00:00.000000000',
#        '2020-06-22T12:00:00.000000000', '2020-06-22T18:00:00.000000000',
#        '2020-06-23T00:00:00.000000000', '2020-06-23T06:00:00.000000000',
#        '2020-06-23T12:00:00.000000000', '2020-06-23T18:00:00.000000000',
#        '2020-06-24T00:00:00.000000000', '2020-06-24T06:00:00.000000000',
#        '2020-06-24T12:00:00.000000000', '2020-06-24T18:00:00.000000000',
#        '2020-06-25T00:00:00.000000000', '2020-06-25T06:00:00.000000000',
#        '2020-06-25T12:00:00.000000000', '2020-06-25T18:00:00.000000000',
#        '2020-06-26T00:00:00.000000000', '2020-06-26T06:00:00.000000000',
#        '2020-06-26T12:00:00.000000000', '2020-06-26T18:00:00.000000000',
#        '2020-06-27T00:00:00.000000000', '2020-06-27T06:00:00.000000000',
#        '2020-06-27T12:00:00.000000000', '2020-06-27T18:00:00.000000000',
#        '2020-06-28T00:00:00.000000000', '2020-06-28T06:00:00.000000000',
#        '2020-06-28T12:00:00.000000000', '2020-06-28T18:00:00.000000000',
#        '2020-06-29T00:00:00.000000000', '2020-06-29T06:00:00.000000000',
#        '2020-06-29T12:00:00.000000000', '2020-06-29T18:00:00.000000000',
#        '2020-06-30T00:00:00.000000000', '2020-06-30T06:00:00.000000000',
#        '2020-06-30T12:00:00.000000000', '2020-06-30T18:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 960B 2020-06-01 ... 2020-06-30T18:00:00
# Attributes:
#     long_name:      Time
#     delta_t:        0000-00-00 06:00:00
#     standard_name:  time
#     axis:           T
#     actual_range:   [1928472. 1937250.]
#     _ChunkSizes:    512

# %% [markdown]
# ## 4. Align temporal cadence
#
# Aggregate the six-hourly air temperatures to daily means with `xr.resample`. Name the resulting DataArray `air_daily`.

# %%
# TODO: use xr.resample to create daily means.

air_daily = air_us.resample(time="1D").mean()

print(air_daily)
#raise NotImplementedError("Create `air_daily`.")
# Out:
# <xarray.Dataset> Size: 46kB
# Dimensions:  (time: 30, lat: 13, lon: 29)
# Coordinates:
#   * lat      (lat) float32 52B 50.0 47.5 45.0 42.5 40.0 ... 27.5 25.0 22.5 20.0
#   * lon      (lon) float32 116B 230.0 232.5 235.0 237.5 ... 295.0 297.5 300.0
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
# Data variables:
#     air      (time, lat, lon) float32 45kB dask.array<chunksize=(1, 13, 29), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 5. Interpolate to the precipitation grid
#
# Use `xr.interp` to interpolate the daily air temperatures onto the precipitation grid (`precip_us.lat` and `precip_us.lon`). Store the interpolated result in `air_interp`.

# %%
# TODO: interpolate the resampled temperature field onto the precipitation grid.

air_interp = air_daily.interp(lat=precip_us["lat"], lon=precip_us["lon"])
print(air_interp)

#raise NotImplementedError("Create `air_interp`.")
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:  (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time     (time) datetime64[ns] 240B 2020-06-01 2020-06-02 ... 2020-06-30
#   * lat      (lat) float32 240B 49.75 49.25 48.75 48.25 ... 21.25 20.75 20.25
#   * lon      (lon) float32 560B 230.2 230.8 231.2 231.8 ... 298.8 299.2 299.8
# Data variables:
#     air      (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
# Attributes:
#     Conventions:                     COARDS
#     title:                           4x daily NMC reanalysis (2014)
#     history:                         created 2017/12 by Hoop (netCDF2.3)
#     description:                     Data is from NMC initialized reanalysis\...
#     platform:                        Model
#     dataset_title:                   NCEP-NCAR Reanalysis 1
#     _NCProperties:                   version=2,netcdf=4.6.3,hdf5=1.10.5
#     References:                      http://www.psl.noaa.gov/data/gridded/dat...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %% [markdown]
# ## 6. Merge the datasets
#
# Convert the aligned arrays into datasets with clear variable names and merge them with `xr.merge`. Save the output as `merged`.

# %%
# TODO: build datasets and merge them into one object named `merged`.

# Convert the aligned arrays into datasets with clear variable names
air_ds = air_interp["air"].rename("air_temperature").to_dataset()
precip_ds = precip_us["precip"].rename("daily_precip").to_dataset()

# Merge the datasets into one object
merged = xr.merge([air_ds, precip_ds])

# Save the merged dataset as `merged`
print(merged)

#raise NotImplementedError("Create `merged`.")
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:          (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time             (time) datetime64[ns] 240B 2020-06-01 ... 2020-06-30
#   * lat              (lat) float32 240B 49.75 49.25 48.75 ... 21.25 20.75 20.25
#   * lon              (lon) float32 560B 230.2 230.8 231.2 ... 298.8 299.2 299.8
# Data variables:
#     air_temperature  (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
#     daily_precip     (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>

# %% [markdown]
# ## 7. Inspect your result
#
# Once your pipeline runs without `NotImplementedError`, evaluate the following cell to sanity-check the merged dataset.

# %%
# The assertions below should pass once you have completed the exercise.
assert set(merged.data_vars) == {"air_temperature", "daily_precip"}
assert merged.air_temperature.dims == merged.daily_precip.dims
print(merged)
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:          (time: 30, lat: 60, lon: 140)
# Coordinates:
#   * time             (time) datetime64[ns] 240B 2020-06-01 ... 2020-06-30
#   * lat              (lat) float32 240B 49.75 49.25 48.75 ... 21.25 20.75 20.25
#   * lon              (lon) float32 560B 230.2 230.8 231.2 ... 298.8 299.2 299.8
# Data variables:
#     air_temperature  (time, lat, lon) float32 1MB dask.array<chunksize=(1, 60, 140), meta=np.ndarray>
#     daily_precip     (time, lat, lon) float32 1MB dask.array<chunksize=(8, 60, 140), meta=np.ndarray>

# %% [markdown]
# ## 8. Check In
#
# - Render both variables at the first timestep on a `cartopy` map to verify alignment visually (PlateCarree works well).
# - Build a scatter plot comparing colocated temperature and precipitation values across the merged domain.
# - Save the merged output with `to_netcdf` for future analysis.

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# 1. Render both variables at the first timestep on a Cartopy map
first_timestep = merged.isel(time=0)

fig, ax = plt.subplots(1, 2, figsize=(15, 6), subplot_kw={"projection": ccrs.PlateCarree()})

# Plot air temperature
first_timestep["air_temperature"].plot(ax=ax[0], transform=ccrs.PlateCarree(), cmap="coolwarm")
ax[0].coastlines()
ax[0].add_feature(cfeature.BORDERS, linestyle=":")
ax[0].set_title("Air Temperature (°C) at First Timestep")

# Plot daily precipitation
first_timestep["daily_precip"].plot(ax=ax[1], transform=ccrs.PlateCarree(), cmap="Blues")
ax[1].coastlines()
ax[1].add_feature(cfeature.BORDERS, linestyle=":")
ax[1].set_title("Daily Precipitation (mm) at First Timestep")

plt.tight_layout()
plt.show()

# %%
# 2. Build a scatter plot comparing colocated temperature and precipitation values
air_flat = merged["air_temperature"].values.flatten()
precip_flat = merged["daily_precip"].values.flatten()

print(air_flat)

plt.figure(figsize=(8, 6))
plt.scatter(air_flat, precip_flat, alpha=0.5, edgecolor="k", linewidth=0.5)
plt.xlabel("Air Temperature (°F)")
plt.ylabel("Daily Precipitation (mm)")
plt.title("Scatter Plot: Temperature vs Precipitation")
plt.grid(True)
plt.show()
# Out:
# [283.65726 283.36176 283.06625 ... 300.99875 300.96725 300.93573]

# %%
# 3. Save the merged dataset to a NetCDF file for future analysis
merged.to_netcdf("merged_climate_data.nc")
